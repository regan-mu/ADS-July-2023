# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
all_months_data = pd.DataFrame()
all_csv_files = [file for file in os.listdir("./Sales_Data/")]
for file in all_csv_files:
    df = pd.read_csv(f"./Sales_Data/{file}")
    all_months_data = pd.concat([all_months_data, df], axis=0)
all_months_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %%
all_months_data.to_csv("./sales.csv", index=False)

# %%
df = pd.read_csv("./sales.csv")
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
df.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
df.shape
# Out:
# (186850, 6)

# %%
df = df.dropna(how="any", axis=0)

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
df.shape
# Out:
# (186305, 6)

# %%
df.duplicated().sum()
# Out:
# 618

# %%
duplicates = df[df.duplicated()]
duplicates
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 31        176585  Bose SoundSport Headphones                 1       99.99
# 1149    Order ID                     Product  Quantity Ordered  Price Each
# 1155    Order ID                     Product  Quantity Ordered  Price Each
# 1302      177795    Apple Airpods Headphones                 1         150
# 1684      178158        USB-C Charging Cable                 1       11.95
# ...          ...                         ...               ...         ...
# 186563  Order ID                     Product  Quantity Ordered  Price Each
# 186632  Order ID                     Product  Quantity Ordered  Price Each
# 186738  Order ID                     Product  Quantity Ordered  Price Each
# 186782    259296    Apple Airpods Headphones                 1         150
# 186785    259297    Lightning Charging Cable                 1       14.95
#
#             Order Date                        Purchase Address
# ...

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185687 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185687 non-null  object
#  1   Product           185687 non-null  object
#  2   Quantity Ordered  185687 non-null  object
#  3   Price Each        185687 non-null  object
#  4   Order Date        185687 non-null  object
#  5   Purchase Address  185687 non-null  object
# dtypes: object(6)
# memory usage: 9.9+ MB

# %%
temp_df=df[df['Order Date'].str[0:2]=='Or']
temp_df
# Out:
#      Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 519  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#      Purchase Address
# 519  Purchase Address

# %%
df = df[df['Order Date'].str[0:2] != 'Or'].copy()

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#            Order Date                      Purchase Address
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001

# %%
df.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered            object
# Price Each                  object
# Order Date          datetime64[ns]
# Purchase Address            object
# dtype: object

# %%
df["Price Each"] = pd.to_numeric(df["Price Each"])
df["Quantity Ordered"] = pd.to_numeric(df["Quantity Ordered"])

# %%
df.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# dtype: object

# %%
neg_price = df.query("`Quantity Ordered` < 0")
neg_price
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address]
# Index: []

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001

# %%
df["Month"] = df["Order Date"].dt.month
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4

# %%
df.tail()
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 186845   259353  AAA Batteries (4-pack)                 3        2.99
# 186846   259354                  iPhone                 1      700.00
# 186847   259355                  iPhone                 1      700.00
# 186848   259356  34in Ultrawide Monitor                 1      379.99
# 186849   259357    USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  Month
# 186845 2019-09-17 20:56:00   840 Highland St, Los Angeles, CA 90001      9
# 186846 2019-09-01 16:00:00  216 Dogwood St, San Francisco, CA 94016      9
# 186847 2019-09-23 07:39:00     220 12th St, San Francisco, CA 94016      9
# 186848 2019-09-19 17:30:00   511 Forest St, San Francisco, CA 94016      9
# 186849 2019-09-30 00:18:00   250 Meadow St, San Francisco, CA 94016      9

# %%
df.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# Month                        int64
# dtype: object

# %%
df["Sale"] = df["Quantity Ordered"] * df["Price Each"]
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month    Sale
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99

# %%
df.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# Month                        int64
# Sale                       float64
# dtype: object

# %%
df = df.rename(columns={"Sale": "Sales"})
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99

# %%
monthly_sales = df.groupby("Month")["Sales"].sum().reset_index(name="TotalSales")
monthly_sales
# Out:
#     Month  TotalSales
# 0       1  1821413.16
# 1       2  2200078.08
# 2       3  2804973.35
# 3       4  3389217.98
# 4       5  3150616.23
# 5       6  2576280.15
# 6       7  2646461.32
# 7       8  2241083.37
# 8       9  2094465.69
# 9      10  3734777.86
# 10     11  3197875.05
# 11     12  4608295.70

# %%
monthly_sales_ordered = monthly_sales.sort_values(by="TotalSales", ascending=False).reset_index(drop=True)
monthly_sales_ordered
# Out:
#     Month  TotalSales
# 0      12  4608295.70
# 1      10  3734777.86
# 2       4  3389217.98
# 3      11  3197875.05
# 4       5  3150616.23
# 5       3  2804973.35
# 6       7  2646461.32
# 7       6  2576280.15
# 8       8  2241083.37
# 9       2  2200078.08
# 10      9  2094465.69
# 11      1  1821413.16

# %%
plt.bar(monthly_sales["Month"], monthly_sales["TotalSales"], color="orange")
plt.title("Sales Per Month (2019)")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()

# %%
import seaborn as sns
sns.barplot(x="Month", y="TotalSales", data=monthly_sales)
plt.title("Sales Per Month (2019)")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99

# %%
def get_city(address):
    """
    """
    city = address.split(",")[1].strip()
    return city

# %%
def get_state(address):
    """
    """
    state = address.split(",")[-1].strip().split(" ")[0].strip()
    return state

# %%
df["City"] = df["Purchase Address"].apply(lambda x: f"{get_city(x)} ({get_state(x)})")
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  Month  \
# ...

# %%
sales_per_city = df.groupby("City")["Sales"].sum().reset_index(name="TotalSales")
sales_per_city
# Out:
#                  City  TotalSales
# 0        Atlanta (GA)  2794199.07
# 1         Austin (TX)  1818044.33
# 2         Boston (MA)  3658627.65
# 3         Dallas (TX)  2765373.96
# 4    Los Angeles (CA)  5448304.28
# 5  New York City (NY)  4661867.14
# 6       Portland (ME)   449321.38
# 7       Portland (OR)  1870010.56
# 8  San Francisco (CA)  8254743.55
# 9        Seattle (WA)  2745046.02

# %%
sns.barplot(x="City", y="TotalSales", data=sales_per_city)
plt.title("Sales Per City (2019)")
plt.xlabel("City")
plt.ylabel("Total Sales")
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  Month  \
# ...

# %%
df.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# Month                        int64
# Sales                      float64
# City                        object
# dtype: object

# %%
df["Hour"] = df["Order Date"].dt.hour
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  Month  \
# ...

# %%
hourly_orders = df.groupby("Hour")["Order ID"].count().reset_index(name="Orders")
hourly_orders
# Out:
#     Hour  Orders
# 0      0    3902
# 1      1    2347
# 2      2    1242
# 3      3     830
# 4      4     852
# 5      5    1320
# 6      6    2481
# 7      7    4002
# 8      8    6252
# 9      9    8740
# 10    10   10929
# 11    11   12392
# 12    12   12573
# 13    13   12115
# 14    14   10965
# 15    15   10159
# 16    16   10359
# 17    17   10884
# 18    18   12263
# 19    19   12886
# 20    20   12218
# 21    21   10905
# 22    22    8808
# 23    23    6262

# %%
plt.plot(hourly_orders["Hour"], hourly_orders["Orders"])
plt.title("Hourly Sales")
plt.xlabel("Hour")
plt.ylabel("Number of Orders")
plt.xticks(hourly_orders["Hour"].values.tolist())
plt.grid(color="gray")
plt.show()

# %%
duplicate_orderIDs = df[df["Order ID"].duplicated(keep=False)].copy()
duplicate_orderIDs
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 3        176560            Google Phone                 1      600.00
# 4        176560        Wired Headphones                 1       11.99
# 18       176574            Google Phone                 1      600.00
# 19       176574    USB-C Charging Cable                 1       11.95
# 32       176586  AAA Batteries (4-pack)                 2        2.99
# ...         ...                     ...               ...         ...
# 186792   259303   AA Batteries (4-pack)                 1        3.84
# 186803   259314        Wired Headphones                 1       11.99
# 186804   259314  AAA Batteries (4-pack)                 2        2.99
# 186841   259350            Google Phone                 1      600.00
# 186842   259350    USB-C Charging Cable                 1       11.95
#
#                 Order Date                        Purchase Address  Month  \
# ...

# %%
duplicate_orderIDs["Grouped"] = duplicate_orderIDs.groupby("Order ID")["Product"].transform(lambda x: ",".join(x))
duplicate_orderIDs
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 3        176560            Google Phone                 1      600.00
# 4        176560        Wired Headphones                 1       11.99
# 18       176574            Google Phone                 1      600.00
# 19       176574    USB-C Charging Cable                 1       11.95
# 32       176586  AAA Batteries (4-pack)                 2        2.99
# ...         ...                     ...               ...         ...
# 186792   259303   AA Batteries (4-pack)                 1        3.84
# 186803   259314        Wired Headphones                 1       11.99
# 186804   259314  AAA Batteries (4-pack)                 2        2.99
# 186841   259350            Google Phone                 1      600.00
# 186842   259350    USB-C Charging Cable                 1       11.95
#
#                 Order Date                        Purchase Address  Month  \
# ...

# %%
sold_together = duplicate_orderIDs.drop_duplicates(subset=["Order ID", "Grouped"])
sold_together
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 3        176560              Google Phone                 1      600.00
# 18       176574              Google Phone                 1      600.00
# 32       176586    AAA Batteries (4-pack)                 2        2.99
# 119      176672  Lightning Charging Cable                 1       14.95
# 129      176681  Apple Airpods Headphones                 1      150.00
# ...         ...                       ...               ...         ...
# 186761   259277                    iPhone                 1      700.00
# 186783   259297                    iPhone                 1      700.00
# 186791   259303    34in Ultrawide Monitor                 1      379.99
# 186803   259314          Wired Headphones                 1       11.99
# 186841   259350              Google Phone                 1      600.00
#
#                 Order Date                        Purchase Address  Month  \
# ...

# %%
from itertools import combinations
from collections import Counter

# %%
counter = Counter()
for row in sold_together["Grouped"]:
    items = row.split(",")
    combine = combinations(items, 2)
    counter.update(combine)

# %%
top_10 = counter.most_common(10)
top_10
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1002),
#  (('Google Phone', 'USB-C Charging Cable'), 985),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 413),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 361),
#  (('iPhone', 'Apple Airpods Headphones'), 360),
#  (('Google Phone', 'Bose SoundSport Headphones'), 220),
#  (('USB-C Charging Cable', 'Wired Headphones'), 159),
#  (('Vareebadd Phone', 'Wired Headphones'), 143),
#  (('Lightning Charging Cable', 'Wired Headphones'), 92)]

# %%
most_products = df.groupby("Product")["Quantity Ordered"].sum().reset_index(name="Quantity")
most_products
# Out:
#                        Product  Quantity
# 0                 20in Monitor      4126
# 1       27in 4K Gaming Monitor      6239
# 2             27in FHD Monitor      7541
# 3       34in Ultrawide Monitor      6192
# 4        AA Batteries (4-pack)     27615
# 5       AAA Batteries (4-pack)     30986
# 6     Apple Airpods Headphones     15637
# 7   Bose SoundSport Headphones     13430
# 8                Flatscreen TV      4813
# 9                 Google Phone      5529
# 10                    LG Dryer       646
# 11          LG Washing Machine       666
# 12    Lightning Charging Cable     23169
# 13          Macbook Pro Laptop      4725
# 14             ThinkPad Laptop      4128
# 15        USB-C Charging Cable     23931
# 16             Vareebadd Phone      2068
# 17            Wired Headphones     20524
# 18                      iPhone      6847

# %%
mean_price = df.groupby("Product")["Price Each"].mean().reset_index(name="MeanPrice")
mean_price
# Out:
#                        Product  MeanPrice
# 0                 20in Monitor     109.99
# 1       27in 4K Gaming Monitor     389.99
# 2             27in FHD Monitor     149.99
# 3       34in Ultrawide Monitor     379.99
# 4        AA Batteries (4-pack)       3.84
# 5       AAA Batteries (4-pack)       2.99
# 6     Apple Airpods Headphones     150.00
# 7   Bose SoundSport Headphones      99.99
# 8                Flatscreen TV     300.00
# 9                 Google Phone     600.00
# 10                    LG Dryer     600.00
# 11          LG Washing Machine     600.00
# 12    Lightning Charging Cable      14.95
# 13          Macbook Pro Laptop    1700.00
# 14             ThinkPad Laptop     999.99
# 15        USB-C Charging Cable      11.95
# 16             Vareebadd Phone     400.00
# 17            Wired Headphones      11.99
# 18                      iPhone     700.00

# %%
sns.barplot(x="Product", y="Quantity", data=most_products)
sns.lineplot(x="Product", y="MeanPrice", data=mean_price)
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(most_products["Product"], most_products["Quantity"], color='g')
ax2.plot(most_products["Product"], mean_price["MeanPrice"], color='b')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price ($)', color='b')
ax1.set_xticklabels(most_products["Product"].values.tolist(), rotation='vertical', size=8)

fig.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10556\10267049.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(most_products["Product"].values.tolist(), rotation='vertical', size=8)
# C:\Users\user\AppData\Local\Temp\ipykernel_10556\10267049.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
